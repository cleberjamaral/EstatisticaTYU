# %%
import pandas as pd

# %%
tb = pd.read_csv("TYU07.csv")

# %%
tb.head()
# Out:
#    Unnamed: 0       Curso     Turno               Ensino médio  \
# 0           1    Mecânica  Integral  Maior parte em particular
# 1           2     Química    Diurno         Somente em pública
# 2           3    Mecânica  Integral  Maior parte em particular
# 3           4  Computação   Noturno         Somente em pública
# 4           5    Produção   Noturno         Somente em pública
#
#             Opinião  Renda  Nota ENEM    IAA
# 0      Insatisfeito   2.96        944  7.117
# 1        Satisfeito   1.16        568  5.051
# 2      Insatisfeito   2.59        679  5.934
# 3  Muito satisfeito   1.04        361  3.895
# 4       Indiferente   1.32        613  5.383

# %%
tb.head()
# Out:
#    Unnamed: 0       Curso     Turno               Ensino médio  \
# 0           1    Mecânica  Integral  Maior parte em particular
# 1           2     Química    Diurno         Somente em pública
# 2           3    Mecânica  Integral  Maior parte em particular
# 3           4  Computação   Noturno         Somente em pública
# 4           5    Produção   Noturno         Somente em pública
#
#             Opinião  Renda  Nota ENEM    IAA
# 0      Insatisfeito   2.96        944  7.117
# 1        Satisfeito   1.16        568  5.051
# 2      Insatisfeito   2.59        679  5.934
# 3  Muito satisfeito   1.04        361  3.895
# 4       Indiferente   1.32        613  5.383
